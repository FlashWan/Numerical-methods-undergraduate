# %% [markdown]
# # Numerical Methods
#
# # Lecture 2: Numerical Differentiation

# %% [markdown]
# ## Learning objectives:
#
#
# * Learn about finite difference approximations to derivatives
#
#
# * Be able to implement forward and central difference methods
#
#
# * Calculate higher-order derivatives
#
#
# * Solve simple ODEs using the finite difference method

# %%
# some imports we will make at the start of every notebook
# later notebooks may add to this with specific SciPy modules

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Differentiation (or taking a derivative) - the continuous definition
#
#
# The classical definition of the derivative of a function $f$ at a point $x_0$ is of course given by:
#
#  $$f'(x_0)=\lim_{h\rightarrow 0} \frac{f(x_0+h)-f(x_0)}{h}. $$
#
#
# **Notation**
#
# 1. Note that the following are all equivalent mathematical ways of writing the derivative of the function $f$ with respect to (w.r.t.) $x$ and evaluated at the location $x_0$:
#
#  $$  f'(x_0) = \frac{df}{dx}(x_0) = \left.\frac{df}{dx}\right|_{x_0}. $$
#
#
# 2. We're using $h$ here to denote a small (potentially infinitesimally small) increment to the $x$ coordinate, as is common. But note that in the literature $\Delta x$ is commonly used to mean the same thing. Also, of course for finite $h$ there is significant overlap here with the mesh spacing in a numerical approximation, as we shall see below, and so $\Delta x$ is also used.

# %% [markdown]
# # Finite differences
#
# Finite differences are a class of approximation method for estimating/computing derivatives of functions.
#
#
# In this lecture we shall largely focus on the case of functions of a single spatial dimension $x$ (e.g. $\;f\equiv f(x)\;$ or $\;u\equiv u(x)$), but these ideas extend for time derivatives (initial-value problems - IVPs - at end of this lecture) and multiple spatial dimensions (PDEs).
#
#
# Approximations to the derivatives of a function can be computed by using weighted sums of function evaluations at a number of points.

# %% [markdown]
# ## The forward difference
#
# For example, we can turn the formal definition of a derivative given above into an approximation rule by replacing the limit as $h$ approaches zero (i.e. the $\text{lim}_{h\rightarrow\infty}$) with a small but finite $\Delta x$ value:
#
# $$ f'(x_0)\approx \frac{f(x_0+\Delta x)-f(x_0)}{\Delta x},\;\;\;\; \Delta x>0. $$
#
# Since this approximate gradient method uses values of $x$ greater than $x_0$ ($\Delta x>0$), this algorithm is known as the **forward difference method**.
#
# The figure below illustrates this approximation.
#
# In the figure the derivative is approximated by the slope of the red line, while the true derivative is the slope of the blue line -- if the second (and/or higher) derivative of the function is large then this approximation might not be very good, unless you make $\Delta x$ very small.
#
# You can see this yourself by varying the value of $\Delta x$ in the code below.

# %%
fig = plt.figure(figsize=(6, 6))
ax1 = plt.subplot(111)
ax1.set_xlim(-0.1, 1.1)
ax1.set_ylim(-0.1, 1.1)
ax1.set_title('Forward difference example', fontsize=16)
ax1.set_xlabel('$x$', fontsize=16)
ax1.set_ylabel('$f(x)$', fontsize=16)
# define our x for plotting purposes
x = np.linspace(0, 1, 1000)

# define our example function and its exact derivative

def f(x):
    return x**2

def df(x):
    return 2 * x

# plot the 'exact' solution
ax1.plot(x, f(x), 'k')
# choose and plot two x locations to take the difference between
x0 = 0.35
dx = 0.5
x1 = x0 + dx
# plot a line representing the discrete derivative
ax1.plot([x0, x1], [f(x0), f(x1)], 'r', label = 'Forward diff. approx. deriv.')
# plot a line representing the exact derivative (given by function f(.)) at x=x0
h = dx/2
ax1.plot([x0 - h, x0 + h], [f(x0) - h * df(x0), f(x0) + h * df(x0)], 'b', label = 'Exact derivative')
# add some axes labels and lines etc
ax1.set_xticks((x0, x1))
ax1.set_xticklabels(('$x_0$', '$x_0+\Delta x$'), fontsize=16)
ax1.plot([x0, x0], [-0.1, f(x0)], 'g:')
ax1.plot([x1, x1], [-0.1, f(x1)], 'g:')
ax1.set_yticks((f(x0), f(x1)))
ax1.set_yticklabels(('$f(x_0)$', '$f(x_0+\Delta x)$'), fontsize=16)
ax1.plot([-0.1, x0], [f(x0), f(x0)], 'g:')
ax1.plot([-0.1, x1], [f(x1), f(x1)], 'g:')
ax1.legend(loc='best', fontsize=14);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fig = plt.figure(figsize=(6, 6))
#       2 ax1 = plt.subplot(111)
#       3 ax1.set_xlim(-0.1, 1.1)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Taylor series to estimate accuracy
#
# We can use a [Taylor series expansion](http://mathworld.wolfram.com/TaylorSeries.html), or *Taylor series analysis*, to estimate the accuracy of the method.
#
# Recall that Taylor series in one dimension tells us that we can approximate the value of the function at a location in terms of its value, and value of its derivative, at a nearby point:
#
# \begin{align*}
# f(x_0+h) & = f(x_0) + hf'(x_0) + \frac{h^2}{2!}f''(x_0) + \frac{h^3}{3!}f'''(x_0) + \ldots\\[5pt]
# & = f(x_0)+hf'(x_0) + \frac{h^2}{2!}f''(x_0) + \mathcal{O}(h^3),
# \end{align*}
#
# where $\mathcal{O}(h^3)$ represents the collection of terms that are third-order in $h$ or higher.
#
# We call this the Taylor series expansion *about (or around) the point $x_0$* (since all the functions in the expansion on the RHS are evaluated at this point).
#
# An equivalent way of writing this expansion would of course be (just define $x$ to be $x_0+h$)
#
# $$f(x) = f(x_0) + (x - x_0) f'(x_0) + \frac{(x - x_0)^2}{2!} f''(x_0) + \frac{(x - x_0)^3}{3!} f'''(x_0) + \mathcal{O}((x - x_0)^4).$$

# %% [markdown]
# #### Taylor series example
#
# *Wikipedia image: The exponential function (in blue), and the sum of the first (n + 1) terms of its Taylor series expansion around the point 0 (in red).*
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/6/62/Exp_series.gif" width=200x>
#
#
# More terms equate with a better approximation valid a larger distance from $x_0$.

# %% [markdown]
# If we rearrange this expression to isolate the gradient term $f'(x_0)$ on the left hand side, we find:
#
#  $$ hf'(x_0)=f(x_0+h)-f(x_0) +O(h^2) $$
#
# and therefore, by dividing through by $h$,
#
#  $$ f'(x_0)=\frac{f(x_0+h)-f(x_0)}{h}+O(h) $$
#
# As we are left with $O(h)$ at the end, we know that the forward difference method is first-order (i.e. $h^1$) -- as we make the spacing $h$ smaller we expect the error in our derivative to fall linearly.

# %% [markdown]
# #### Order of convergence - higher generally better
#
# For general numerical methods we generally strive for something better than this - if we halve our $h$ we would like our error to drop super-linearly: i.e. by a factor of 4 (second-order method) or 8 (third-order method) or more.
#
# But note that as we shall see when we start to solve some differential equations, reducing the size of $h$ (i.e. refining our computational mesh) does generally come at the expense of doing more work overall.  So there is a trade-off in accuracy vs cost.

# %% [markdown]
# ## <span style="color:blue">Exercise 2.1: Compute first derivative using forward differencing</span>
#
# Use the forward difference scheme to compute an approximation to $f'(2.36)$ from the following data:
#
# $f(2.36) = 0.85866$
#
# $f(2.37) = 0.86289$
#
# You should get an answer of 0.423.

# %% [markdown]
# ## The central difference
#
# In an attempt to derive a more accurate method we use two Taylor series expansions; one in the positive $x$ direction from $x_0$, and one in the negative direction.
#
# Since we hope to achieve better than first-order accuracy, we include an extra term in the series:
#
# \begin{align*}
# f(x_0+ \Delta x) &= f(x_0)+\Delta x f'(x_0)+\frac{\Delta x^2}{2}f''(x_0) + \mathcal{O}(\Delta x^3)\\[5pt]
# f(x_0- \Delta x) &= f(x_0)- \Delta x f'(x_0)+\frac{(-\Delta x)^2}{2}f''(x_0) + \mathcal{O}((-\Delta x)^3).
# \end{align*}
#
# Using the fact that $(-\Delta x)^2=\Delta x^2$ and the absolute value signs from the definition of $\mathcal{O}$ (that is we don't worry about signs when using the $\mathcal{O}$ notation), this is equivalent to:
#
# \begin{align*}
# f(x_0+\Delta x) &= f(x_0)+\Delta xf'(x_0)+\frac{\Delta x^2}{2}f''(x_0) + \mathcal{O}(\Delta x^3),\\[5pt]
# f(x_0-\Delta x) &= f(x_0)-\Delta xf'(x_0)+\frac{\Delta x^2}{2}f''(x_0) + \mathcal{O}(\Delta x^3).
# \end{align*}
#
# Remember that we are looking for an expression for $f'(x_0)$. Noticing the sign change between the derivative terms in the two equations, we subtract the second equation from the first to give:
#
# $$ f(x_0+\Delta x)-f(x_0-\Delta x)=2\Delta xf'(x_0) + \mathcal{O}(\Delta x^3).$$
#
# Finally, we can rearrange to get an expression for $f'(x_0)$:
#
# $$ f'(x_0)=\frac{f(x_0+\Delta x)-f(x_0-\Delta x)}{2\Delta x} + O(\Delta x^2),$$
#
# which, contrary to the first-order forward and backward differences seen above, is an approximation to the derivative that is second-order accurate.

# %% [markdown]
# By considering an interval symmetric about $x_0$, we have created a second-order approximation for the derivative of $f$.
#
# This symmetry gives the scheme its name: the central difference method.
#
# The figure below illustrates this scheme. The derivative is approximated by the slope of the red line, while the true derivative is the slope of the blue line.
#
# Even without the analysis above it's hopefully clear visually why this should in general give a lower error than both the forward and backward difference approaches.
#
# The analysis of the two methods does tell us that as we halve $h$ the error should drop by a factor 4 rather than the 2 we get for the first-order forward or backward differencing.

# %%
fig = plt.figure(figsize=(6, 6))
ax1 = plt.subplot(111)
ax1.set_xlim(-0.1, 1.1)
ax1.set_ylim(-0.1, 1.1)
# ax.grid(True)
ax1.set_title('Central difference example', fontsize=16)
ax1.set_xlabel('$x$', fontsize=16)
ax1.set_ylabel('$f(x)$', fontsize=16)
# define our x for plotting purposes
x = np.linspace(0, 1, 1000)

# define our example function and its exact derivative

def f(x):
    return x**2

def df(x):
    return 2 * x

# plot the exact solution
ax1.plot(x, f(x), 'k')
# choose and plot two x locations to take the difference between
dx = 0.4
x0 = 0.5
xl = x0 - dx
xr = x0 + dx
# plot a line representing the discrete derivative
ax1.plot([xl, xr], [f(xl), f(xr)], 'r', label = 'Central diff. approx. deriv.')
# plot a line representing the exact derivative at x=x0
h = dx / 2
ax1.plot([x0 - h, x0 + h], [f(x0) - h * df(x0), f(x0) + h * df(x0)], 'b', label = 'Exact derivative')
# add some axes labels and lines etc
ax1.set_xticks((xl, x0, xr))
ax1.set_xticklabels(('$x_0-\Delta x$', '$x_0$', '$x_0+\Delta x$'), fontsize=16)
ax1.plot([xl, xl], [-0.1, f(xl)], 'k:')
ax1.plot([xr, xr], [-0.1, f(xr)], 'k:')
ax1.plot([x0, x0], [-0.1, f(x0)], 'k:')
ax1.set_yticks((f(xl), f(xr)))
ax1.set_yticklabels(('$f(x_0-\Delta x)$', '$f(x_0+\Delta x)$'), fontsize=16)
ax1.plot([-0.1, xl], [f(xl), f(xl)], 'k:')
ax1.plot([-0.1, xr], [f(xr), f(xr)], 'k:')
ax1.legend(loc='best', fontsize=14);

# %% [markdown]
# ## <span style="color:blue">Exercise 2.2: Compute first derivative using central differencing</span>
#
# Use the data below to compute $f'(0.2)$ using central differencing:
#
# $$f(0.1) = 0.078348$$
# $$f(0.2) = 0.138910$$
# $$f(0.3) = 0.192916$$
#
# You should get 0.57284

# %% [markdown]
# ## <span style="color:blue">Example: Write a function to perform numerical differentiation</span>
#
# As covered above, the expression
#
# $$\frac{f(x+\Delta x) - f(x-\Delta x)}{2\Delta x},$$
#
# can be used to find an approximate derivative of the function $f(x)$ provided that $\Delta x$ is appropriately small.
#
# Let's write a function `diff(f, x, dx = 1.0e-6)` that returns the approximation of the derivative of a mathematical function represented by a Python function `f(x)`.
#
# Let's apply the above formula to differentiate $\,f(x) = e^x\,$ at $\,x = 0$, $\,f(x) = e^{−2x}\,$ at $\,x = 0$, $\,f(x) = \cos(x)\,$ at $\,x = 2\pi$, and $\,f(x) = \ln(x)\,$ at $\,x = 1\,$, i.e. functions we know the exact derivative of.
#
# In each case, using $\,\Delta x = 0.01$, let's write out the error, i.e. the difference between the exact derivative and the result of the formula above.

# %%
def diff(f, x, dx=1e-6):
    numerator = f(x + dx) - f(x - dx)
    derivative = numerator / ( 2.0 * dx )
    return derivative

dx = 0.01
x = 0
f = np.exp
derivative = diff(f, x, dx)
print("The approximate derivative of exp(x) at x = 0 is: %f. The error is %f."
      % (derivative, abs(derivative - 1)))
x = 0

def g(x):
    return np.exp(-2*x)

derivative = diff(g, x, dx)
print('The approximate derivative of exp(-2*x) at x = 0 is: {0:.5f}.  The error is {1:.5f}.'
        .format(derivative, abs(derivative - (-2.0))))

x = 2*np.pi
f = np.cos
derivative = diff(f, x, dx)
print('The approximate derivative of cos(x) at x = 2*pi is: {0:.5f}.  The error is {1:.5f}.'
        .format(derivative, abs(derivative - 0)))

x =1
f = np.log
derivative = diff(f, x, dx)
print('The approximate derivative of ln(x) at x = 0 is: {0:.5f}.  The error is {1:.5f}.'
        .format(derivative, abs(derivative - 1)))
# Out:
# The approximate derivative of exp(x) at x = 0 is: 1.000017. The error is 0.000017.
# The approximate derivative of exp(-2*x) at x = 0 is: -2.00013.  The error is 0.00013.
# The approximate derivative of cos(x) at x = 2*pi is: 0.00000.  The error is 0.00000.
# The approximate derivative of ln(x) at x = 0 is: 1.00003.  The error is 0.00003.

# %% [markdown]
# ## <span style="color:blue">Exercise 2.3: Compute the derivative of $\sin(x)$</span>
#
# Compute
#
# $$\frac{d(\sin x)}{dx}\qquad\textrm{at}\qquad x = 0.8$$
#
# using (a) forward differencing and (b) central differencing.
#
# Write some code that evaluates these derivatives for decreasing values of $h$ (start with $h=1.0$ and keep halving) and compare the values against the exact solution.
#
# Plot the convergence of your two methods.

# %%
def fdiff(f, x, dx):
    numerator = f(x + dx) - f(x)
    derivative = numerator / dx
    return derivative

def cdiff(f, x, dx):
    numerator = f(x + dx) - f(x - dx)
    derivative = numerator / (2*dx)
    return derivative

# Define the function representing sin(x)
def h(x):
    return np.sin(x)

dx = 0.1  # Initialize dx
while dx > 0:
    x = 0.8  # Set the value of x where you want to calculate the derivative
    derivative = fdiff(h, x, dx)
    print('Forward difference: The approximate derivative of sin(x) at x = 0.8 is: {0:.5f}.  The error is {1:.5f}. dx = {2}'
          .format(derivative, abs(derivative - np.cos(x)), dx))
    dx = dx/2

    x = 0.8  # Set the value of x where you want to calculate the derivative
    derivative = cdiff(h, x, dx)
    print('Central difference: The approximate derivative of sin(x) at x = 0.8 is: {0:.5f}.  The error is {1:.5f}. dx = {2}'
          .format(derivative, abs(derivative - np.cos(x)), dx))
    dx = dx/2
# Out:
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.65971.  The error is 0.03700. dx = 0.1
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69642.  The error is 0.00029. dx = 0.05
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.68767.  The error is 0.00904. dx = 0.025
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69669.  The error is 0.00002. dx = 0.0125
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69446.  The error is 0.00225. dx = 0.00625
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 0.003125
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69615.  The error is 0.00056. dx = 0.0015625
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 0.00078125
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69657.  The error is 0.00014. dx = 0.000390625
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 0.0001953125
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69667.  The error is 0.00004. dx = 9.765625e-05
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 4.8828125e-05
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69670.  The error is 0.00001. dx = 2.44140625e-05
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 1.220703125e-05
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69670.  The error is 0.00000. dx = 6.103515625e-06
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 3.0517578125e-06
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 1.52587890625e-06
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 7.62939453125e-07
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 3.814697265625e-07
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 1.9073486328125e-07
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 9.5367431640625e-08
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 4.76837158203125e-08
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 2.384185791015625e-08
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 1.1920928955078126e-08
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 5.960464477539063e-09
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 2.9802322387695314e-09
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 1.4901161193847657e-09
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 7.450580596923829e-10
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 3.7252902984619143e-10
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 1.8626451492309571e-10
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 9.313225746154786e-11
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 4.656612873077393e-11
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 2.3283064365386964e-11
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69671.  The error is 0.00000. dx = 1.1641532182693482e-11
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69672.  The error is 0.00001. dx = 5.820766091346741e-12
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69672.  The error is 0.00001. dx = 2.9103830456733705e-12
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69672.  The error is 0.00001. dx = 1.4551915228366853e-12
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69672.  The error is 0.00001. dx = 7.275957614183426e-13
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69672.  The error is 0.00001. dx = 3.637978807091713e-13
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69641.  The error is 0.00030. dx = 1.8189894035458566e-13
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69702.  The error is 0.00031. dx = 9.094947017729283e-14
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69824.  The error is 0.00154. dx = 4.5474735088646414e-14
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69824.  The error is 0.00154. dx = 2.2737367544323207e-14
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.69336.  The error is 0.00335. dx = 1.1368683772161604e-14
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.70312.  The error is 0.00642. dx = 5.684341886080802e-15
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.70312.  The error is 0.00642. dx = 2.842170943040401e-15
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.70312.  The error is 0.00642. dx = 1.4210854715202005e-15
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.62500.  The error is 0.07171. dx = 7.105427357601002e-16
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.62500.  The error is 0.07171. dx = 3.552713678800501e-16
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 1.25000.  The error is 0.55329. dx = 1.7763568394002506e-16
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 1.25000.  The error is 0.55329. dx = 8.881784197001253e-17
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.4408920985006264e-17
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.2204460492503132e-17
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.1102230246251566e-17
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.551115123125783e-18
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.7755575615628915e-18
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.3877787807814458e-18
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.938893903907229e-19
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.4694469519536144e-19
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.7347234759768072e-19
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.673617379884036e-20
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.336808689942018e-20
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.168404344971009e-20
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.0842021724855045e-20
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.4210108624275225e-21
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.7105054312137612e-21
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.3552527156068806e-21
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.776263578034403e-22
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.3881317890172015e-22
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.6940658945086008e-22
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.470329472543004e-23
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.235164736271502e-23
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.117582368135751e-23
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.0587911840678755e-23
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.2939559203393774e-24
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.6469779601696887e-24
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.3234889800848444e-24
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.617444900424222e-25
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.308722450212111e-25
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.6543612251060554e-25
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.271806125530277e-26
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.1359030627651386e-26
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.0679515313825693e-26
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.0339757656912847e-26
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.169878828456423e-27
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.5849394142282116e-27
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.2924697071141058e-27
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.462348535570529e-28
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.2311742677852645e-28
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.6155871338926323e-28
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.077935669463161e-29
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.0389678347315807e-29
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.0194839173657903e-29
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.0097419586828952e-29
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.048709793414476e-30
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.524354896707238e-30
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.262177448353619e-30
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.310887241768095e-31
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.1554436208840474e-31
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.5777218104420237e-31
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.888609052210118e-32
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.944304526105059e-32
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.9721522630525296e-32
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.860761315262648e-33
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.930380657631324e-33
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.465190328815662e-33
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.232595164407831e-33
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.162975822039155e-34
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.0814879110195775e-34
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.5407439555097888e-34
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.703719777548944e-35
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.851859888774472e-35
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.925929944387236e-35
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.62964972193618e-36
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.81482486096809e-36
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.407412430484045e-36
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.2037062152420225e-36
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.018531076210112e-37
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.009265538105056e-37
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.504632769052528e-37
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.52316384526264e-38
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.76158192263132e-38
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.88079096131566e-38
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.4039548065783e-39
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.70197740328915e-39
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.350988701644575e-39
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.1754943508222876e-39
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.877471754111438e-40
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.938735877055719e-40
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.4693679385278595e-40
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.346839692639297e-41
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.6734198463196487e-41
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.8367099231598243e-41
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.183549615799122e-42
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.591774807899561e-42
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.2958874039497804e-42
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.1479437019748902e-42
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.739718509874451e-43
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.8698592549372255e-43
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.4349296274686128e-43
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.174648137343064e-44
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.587324068671532e-44
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.793662034335766e-44
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.96831017167883e-45
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.484155085839415e-45
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.2420775429197074e-45
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.1210387714598537e-45
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.6051938572992686e-46
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.8025969286496343e-46
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.4012984643248171e-46
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.006492321624086e-47
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.503246160812043e-47
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.7516230804060214e-47
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.758115402030107e-48
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.3790577010150536e-48
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.1895288505075268e-48
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.0947644252537634e-48
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.473822126268817e-49
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.7369110631344085e-49
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.3684555315672042e-49
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.842277657836021e-50
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.4211388289180106e-50
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.7105694144590053e-50
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.552847072295027e-51
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.276423536147513e-51
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.1382117680737566e-51
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.0691058840368783e-51
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.3455294201843916e-52
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.6727647100921958e-52
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.3363823550460979e-52
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.6819117752304895e-53
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.3409558876152447e-53
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.6704779438076224e-53
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.352389719038112e-54
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.176194859519056e-54
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.088097429759528e-54
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.044048714879764e-54
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.22024357439882e-55
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.61012178719941e-55
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.305060893599705e-55
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.525304467998525e-56
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.2626522339992624e-56
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.6313261169996312e-56
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.156630584998156e-57
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.078315292499078e-57
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.039157646249539e-57
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.0195788231247695e-57
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.0978941156238476e-58
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.5489470578119238e-58
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.2744735289059619e-58
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.3723676445298095e-59
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.1861838222649047e-59
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.5930919111324524e-59
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.965459555662262e-60
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.982729777831131e-60
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.9913648889155655e-60
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.956824444577827e-61
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.9784122222889136e-61
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.4892061111444568e-61
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.2446030555722284e-61
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.223015277861142e-62
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.111507638930571e-62
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.5557538194652855e-62
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.778769097326428e-63
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.889384548663214e-63
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.944692274331607e-63
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.723461371658034e-64
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.861730685829017e-64
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.4308653429145086e-64
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.2154326714572543e-64
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.0771633572862715e-65
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.0385816786431358e-65
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.5192908393215679e-65
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.596454196607839e-66
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.7982270983039197e-66
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.8991135491519599e-66
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.495567745759799e-67
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.7477838728798996e-67
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.3738919364399498e-67
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.1869459682199749e-67
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.9347298410998745e-68
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.9673649205499373e-68
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.4836824602749686e-68
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.418412301374843e-69
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.7092061506874216e-69
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.8546030753437108e-69
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.273015376718554e-70
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.636507688359277e-70
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.3182538441796385e-70
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.1591269220898192e-70
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.795634610449096e-71
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.897817305224548e-71
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.448908652612274e-71
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.24454326306137e-72
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.622271631530685e-72
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.8111358157653426e-72
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.055679078826713e-73
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.5278395394133564e-73
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.2639197697066782e-73
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.1319598848533391e-73
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.6597994242666955e-74
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.8298997121333478e-74
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.4149498560666739e-74
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.074749280333369e-75
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.5373746401666847e-75
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.7686873200833424e-75
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.843436600416712e-76
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.421718300208356e-76
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.210859150104178e-76
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.105429575052089e-76
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.527147875260445e-77
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.7635739376302224e-77
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.3817869688151112e-77
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.908934844075556e-78
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.454467422037778e-78
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.727233711018889e-78
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.636168555094445e-79
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.3180842775472226e-79
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.1590421387736113e-79
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.0795210693868056e-79
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.397605346934028e-80
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.698802673467014e-80
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.349401336733507e-80
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.747006683667535e-81
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.3735033418337676e-81
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.6867516709168838e-81
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.433758354584419e-82
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.2168791772922095e-82
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.1084395886461048e-82
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.0542197943230524e-82
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.271098971615262e-83
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.635549485807631e-83
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.3177747429038155e-83
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.588873714519077e-84
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.2944368572595387e-84
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.6472184286297693e-84
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.236092143148847e-85
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.1180460715744234e-85
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.0590230357872117e-85
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.0295115178936058e-85
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.147557589468029e-86
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.5737787947340146e-86
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.2868893973670073e-86
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.4344469868350365e-87
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.2172234934175183e-87
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.6086117467087591e-87
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.043058733543796e-88
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.021529366771898e-88
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.010764683385949e-88
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.0053823416929745e-88
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.026911708464872e-89
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.513455854232436e-89
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.256727927116218e-89
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.28363963558109e-90
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.141819817790545e-90
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.5709099088952726e-90
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.854549544476363e-91
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.9272747722381815e-91
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.9636373861190907e-91
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.818186930595454e-92
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.909093465297727e-92
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.4545467326488634e-92
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.2272733663244317e-92
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.1363668316221585e-93
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.0681834158110793e-93
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.5340917079055396e-93
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.670458539527698e-94
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.835229269763849e-94
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.9176146348819245e-94
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.588073174409623e-95
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.7940365872048114e-95
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.3970182936024057e-95
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.1985091468012028e-95
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.992545734006014e-96
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.996272867003007e-96
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.4981364335015035e-96
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.490682167507518e-97
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.745341083753759e-97
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.8726705418768794e-97
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.363352709384397e-98
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.6816763546921986e-98
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.3408381773460993e-98
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.1704190886730496e-98
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.852095443365248e-99
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.926047721682624e-99
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.463023860841312e-99
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.31511930420656e-100
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.65755965210328e-100
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.82877982605164e-100
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.1438991302582e-101
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.5719495651291e-101
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.28597478256455e-101
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.142987391282275e-101
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.714936956411375e-102
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.8574684782056876e-102
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.4287342391028438e-102
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.143671195514219e-103
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.5718355977571095e-103
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.7859177988785548e-103
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.929588994392774e-104
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.464794497196387e-104
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.2323972485981934e-104
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.1161986242990967e-104
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.580993121495484e-105
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.790496560747742e-105
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.395248280373871e-105
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.976241401869355e-106
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.4881207009346773e-106
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.7440603504673386e-106
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.720301752336693e-107
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.3601508761683466e-107
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.1800754380841733e-107
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.0900377190420866e-107
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.450188595210433e-108
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.7250942976052166e-108
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.3625471488026083e-108
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.812735744013042e-109
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.406367872006521e-109
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.7031839360032604e-109
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.515919680016302e-110
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.257959840008151e-110
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.1289799200040755e-110
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.0644899600020377e-110
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.322449800010189e-111
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.6612249000050943e-111
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.3306124500025472e-111
# ...
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.2030456845295375e-287
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.1015228422647688e-287
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.0507614211323844e-287
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.253807105661922e-288
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.626903552830961e-288
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.3134517764154805e-288
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.567258882077402e-289
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.283629441038701e-289
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.6418147205193506e-289
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.209073602596753e-290
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.1045368012983765e-290
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.0522684006491882e-290
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.0261342003245941e-290
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.1306710016229706e-291
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.5653355008114853e-291
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.2826677504057426e-291
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.413338752028713e-292
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.2066693760143566e-292
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.6033346880071783e-292
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.016673440035892e-293
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.008336720017946e-293
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.004168360008973e-293
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.0020841800044864e-293
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.010420900022432e-294
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.505210450011216e-294
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.252605225005608e-294
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.26302612502804e-295
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.13151306251402e-295
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.56575653125701e-295
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.82878265628505e-296
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.914391328142525e-296
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.9571956640712626e-296
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.785978320356313e-297
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.8929891601781565e-297
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.4464945800890782e-297
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.2232472900445391e-297
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.116236450222696e-298
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.058118225111348e-298
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.529059112555674e-298
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.64529556277837e-299
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.822647781389185e-299
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.9113238906945924e-299
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.556619453472962e-300
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.778309726736481e-300
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.3891548633682405e-300
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.1945774316841202e-300
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.972887158420601e-301
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.9864435792103006e-301
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.4932217896051503e-301
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.466108948025751e-302
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.7330544740128757e-302
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.8665272370064379e-302
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.332636185032189e-303
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.6663180925160947e-303
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.3331590462580473e-303
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.1665795231290237e-303
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.832897615645118e-304
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.916448807822559e-304
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.4582244039112796e-304
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.291122019556398e-305
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.645561009778199e-305
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.8227805048890995e-305
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 9.113902524445497e-306
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.556951262222749e-306
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.2784756311113743e-306
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.1392378155556872e-306
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.696189077778436e-307
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.848094538889218e-307
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.424047269444609e-307
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 7.120236347223045e-308
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.5601181736115224e-308
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.780059086805761e-308
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.900295434028804e-309
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.4501477170144e-309
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.225073858507203e-309
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.1125369292536e-309
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.562684646268e-310
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.781342323134e-310
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.390671161567e-310
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.953355807835e-311
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.4766779039173e-311
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.7383389519587e-311
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.691694759796e-312
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.3458473799e-312
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.172923689946e-312
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.086461844973e-312
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.4323092249e-313
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.71615461245e-313
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.3580773062e-313
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.790386531e-314
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.3951932657e-314
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.697596633e-314
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.48798316e-315
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.24399158e-315
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.121995793e-315
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.060997896e-315
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.30498946e-316
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.65249473e-316
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.3262474e-316
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.631237e-317
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.315618e-317
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.657809e-317
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.28905e-318
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.144524e-318
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.07226e-318
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.03613e-318
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.18067e-319
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.59034e-319
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.29514e-319
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.4757e-320
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3.238e-320
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.619e-320
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 8.093e-321
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 4.046e-321
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.026e-321
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.013e-321
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5.04e-322
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 2.5e-322
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.3e-322
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 6.4e-323
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 3e-323
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1.5e-323
# Forward difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 1e-323
# Central difference: The approximate derivative of sin(x) at x = 0.8 is: 0.00000.  The error is 0.69671. dx = 5e-324

# %% [markdown]
# You should get something that looks like this
#
# !["Convergence plot"](images/fd_cd_convergence.png)

# %% [markdown]
# ## Approximating second derivatives
#
# Numerical differentiation may be extended to the second derivative by noting that the second derivative is the derivative of the first derivative.
#
# That is, if we define a new function $g$ where:
#
# $$ g(x) = f'(x), $$
#
# then
#
# $$ f''(x) = g'(x), $$
#
# a consequence of this (obvious) observation is that we can just apply our differencing formula twice in order to achieve a second derivative.
#
# And so on for even higher  derivatives!

# %% [markdown]
# We have noted above that the central difference method, being second-order accurate, is superior to the forward difference method so we will choose to extend that.
#
# In order to calculate $f''(x_0)$ using a central difference method, we first calculate $f'(x)$ for each of two half intervals, one to the left of $x_0$ and one to the right:
#
# \begin{align*}
# f'\left(x_0+\frac{\Delta x}{2}\right) & \approx \frac{f(x_0+\Delta x)-f(x_0)}{\Delta x},\\[10pt]
# f'\left(x_0-\frac{\Delta x}{2}\right) & \approx \frac{f(x_0)-f(x_0-\Delta x)}{\Delta x}.
# \end{align*}
#
# [NB. We make this choice since we have a vision to ultimately end up with an approximation that utilises a three-point stencil].
#
# Of course the formula on the RHS of these two equations we recognise from above as first-order forward and backward differences, if we were to consider the derivatives on the LHS to be evaluated at $x_0$.
#
# However, by considering the LHS at $x_0\pm \Delta x/2$ they are in actual fact second-order *central* differences where the denominator of the RHS is $2\times (\Delta x/2)$.
#
# [This may seem a bit weird, but is just showing that there are sometimes more than one way to interpret a numerical approximation].
#
# We can now calculate the second derivative making use of these two values within another central difference.
#
# But we must note again that these two values are telling us $f'(x)$ at the points $x_0\pm{\Delta x}/{2}$, which are only $\Delta x$ rather than $2\Delta x$ apart.
# We must remember this in the denominator of the central difference formula to yield
#
# \begin{align}
#     f''(x_0)&\approx\frac{f'(x_0+\frac{\Delta x}{2})-f'(x_0-\frac{\Delta x}{2})}{\Delta x}\\[5pt]
#     &\approx\frac{\frac{f(x_0+\Delta x)-f(x_0)}{\Delta x}-\frac{f(x_0)-f(x_0-h)}{\Delta x}}{\Delta x}\\[5pt]
#     &\approx\frac{f(x_0+\Delta x)-2f(x_0)+f(x_0-\Delta x)}{\Delta x^2}.
# \end{align}

# %% [markdown]
# ## <span style="color:blue">Exercise 2.4: Compute second derivative</span>
#
# Calculate the second derivative $f''$ at $x = 1$ using the data below:
#
# $f(0.84) = 0.431711$
#
# $f(0.92) = 0.398519$
#
# $f(1.00) = 0.367879$
#
# $f(1.08) = 0.339596$
#
# $f(1.16) = 0.313486$
#
# You should get 0.36828

# %% [markdown]
# ## Aside: Non-central differencing and differentiation by polynomial fit
#
# In this particular case we were given more data than we actually used. An alternative approach would be to use *non-centred differencing*, e.g. the following is also a valid approximation to the second derivative
#
# $$
# \begin{align}
#     f''(x_0)\approx\frac{f(x_0+2\Delta x)-2f(x_0+\Delta x)+f(x_0)}{\Delta x^2}
# \end{align}$$
#
# This can come in handy if we need to approximate the value of derivatives at or near to a boundary where we don't have data beyond that boundary.
#
# If we wanted to use all of this data, an alternative would be to fit a polynomial to this data, and then differentiate this analytical expression exactly to approximate the derivative at any point between 0.84 and 1.16 (recalling that extrapolation is dangerous).

# %% [markdown]
# ## Numerical methods for ODEs
#
# One of the most important applications of numerical mathematics in the sciences is the numerical solution of ordinary differential equations (ODEs). This is a vast topic which rapidly becomes somewhat advanced, so we will restrict ourselves here to a very brief introduction to the solution of first order ODEs.
#
# Suppose we have the general first-order ODE:
#
# \begin{align}
# u'(t)&=f(u(t),t) \\
# u(t_0)&=u_0
# \end{align}
#
# [Notation: For $u\equiv u(t)$, $\frac{du}{dt}=u'=\dot{u}$.]

# %% [markdown]
# That is, the derivative of $u$ with respect to $t$ is some known function of $u$ and $t$, and we also know the initial condition of $u$ at some initial time $t_0$.
#
# If we manage to solve this equation analytically, the solution will be a function $u(t)$ which is defined for every $t>t_0$. In common with all of the numerical methods we will encounter in this module, our objective is to find an approximate solution to the ODE at a finite set of points. In this case, we will attempt to find approximate solutions at $t=t_0,\,t_0+\Delta t,\,t_0+2\Delta t\,,t_0+3\Delta t,\,\ldots$.
#
# It is frequently useful to think of the independent variable, $t$, as representing time. A numerical method steps forward in time units of $\Delta t$, attempting to calculate $u(t+\Delta t)$ in using the previously calculated value $u(t)$.

# %% [markdown]
# ### Euler's method
#
# To derive a numerical method, we can first turn once again to the Taylor
# series. In this case, we could write:
#
# $$ u(t+\Delta t)=u(t)+\Delta t u'(t) + O(\Delta t^2) $$
#
# Using the definition of our ODE above, we can substitute in for $u'(t)$:
#
# $$ u(t+\Delta t)=u(t)+ \Delta t f(u(t),t)+ O(\Delta t^2).$$
#
# Notice that the value of $u$ used in the evaluation of $f$ is that at time $t$. This simple scheme is named **Euler's method** after the 18th century Swiss mathematician, Leonard Euler.

# %% [markdown]
# Dropping the $O(\Delta t^2)$ terms, we have a scheme we can easily implement in code:
#
# $$ u(t+\Delta t)=u(t)+ \Delta t f(u(t),t)$$
#
#
# This is what is known as an explicit method, because the function $f$ in this relation is evaluated at the old time level $t$
# -- i.e. we have all the information required at time $t$ to explicitly compute the right-hand-side,
# and hence easily find the new value for $u(t+\Delta t)$.
#
# This form of the method is therefore more correctly called either Explicit Euler or Forward Euler.  We could also evaluate the RHS at some time between $t$ and $t+\Delta t$ (in the case of $t+h$ this method is called Implicit or Backward Euler) this is more complex to solve for the new $u(t+\Delta t)$ but can have advantageous accuracy and stability properties.

# %% [markdown]
# The formula given is used to calculate the value of $u(t)$ one time step forward from the last known value. The error is therefore the local truncation error. If we actually wish to know the value at some fixed time $T$ then we will have to calculate $(T-t_0)/h$ steps of the method. This sum over $O(1/\Delta t)$ steps results in a global truncation error for Euler's method of $O(\Delta t)$.
#
# In other words, Euler's method is only first-order accurate -- if we halve $\Delta t$ we will need to do double the amount of work and the error should correspondingly halve; if we had a second-order method we would expect the error to reduce by a factor of 4 for every doubling in effort!

# %% [markdown]
# To illustrate Euler's method, and convey the fundamental idea of all time stepping methods, we'll use Euler's method to solve one of the simplest of all ODEs:
#
# $$ u'(t)=u(t),$$
# $$ u(0)=1.$$
#
# We know, of course, that the solution to this equation is $u(t)=e^t$, but let's ignore that for one moment and evaluate $u(0.1)$ using Euler's method with steps of $0.05$. The first step is:
#
# $$\begin{align}
#   u(0.05)&\approx u(0)+0.05u'(0)\\
#   &\approx1+.05u(0)\\
#   &\approx1+.05\times1\\
#   &\approx 1.05
# \end{align}$$

# %% [markdown]
# Now that we know $u(0.05)$, we can calculate the second step:
#
# $$
# \begin{align}
#   u(0.1)&\approx u(0.05)+0.05u'(0.05)\\
#   &\approx1+.05u(0.05)\\
#   &\approx 1.05+.05\times1.05\\
#   &\approx 1.1025
# \end{align}$$
#
# Now the actual value of $e^{0.1}$ is around $1.1051$ so we're a couple of percent off even over a very short time interval and only a couple of steps of the algorithm.

# %% [markdown]
# ## <span style="color:blue">Exercise 2.5: Implementing Forward Euler's method</span>
#
# Write a function *euler*( *f*, *u0*, *t0*, *t_max*, *h*) that takes as arguments the function $f(u,t)$ on the RHS of our ODE,
# an initial value for $u$, the start and end time of the integration, and the time step.
#
# Use it to integrate the following ODE problems up to time $t=10$
#
# $$u'(t)=u(t),\quad u(0)=1$$
#
# and
#
# $$u'(t)=\cos(t),\quad u(0)=0$$
#
# and plot the results. A template to get you started is below.

# %%
def euler(f,u0,t0,t_max,dt):
    u=u0; t=t0
    # these lists will store all solution values 
    # and associated time levels for later plotting
    u_all=[u0]; t_all=[t0]
    
    
    while ... add your code here
    
    
    
    
    
    
    return(u_all,t_all)


def f(u,t):
    val = u
    return val

(u_all,t_all) = euler(f,1.0,0.0,10.0,0.1)

# %% [markdown]
# ### Heun's method
#
# Euler's method is first-order accurate because it calculates the derivative using only the information available at the beginning of the time step. As we observed previously, higher-order convergence can be obtained if we also employ information from other points in the interval. Heun's method may be derived by attempting to use derivative information at both the start and the end of the interval:
#
# $$
# \begin{align}
#   u(t+\Delta t)&\approx u(t)+\frac{\Delta t}{2}\left(u'(t)+u'(t+\Delta t)\right)\\
#   &\approx u(t)+\frac{\Delta t}{2}\big(f(u(t),t)+f(u(t+\Delta t),t+\Delta t)\big)
# \end{align}$$
#
# The difficulty with this approach is that we now require $u(t+\Delta t)$ in order to calculate the final term in the equation, and that's what we set out to calculate so we don't know it yet! So at this point we have an example of an implicit algorithm and at this stage the above ODE solver would be referred to as the trapezoidal method if we could solve it exactly for $u(t+\Delta t)$.

# %% [markdown]
# Perhaps the simplest solution to this dilemma, the one adopted in Heun's method, is to use a first guess at $x(t+\Delta t)$ calculated using Euler's method:
#
# $$ \tilde{u}(t+\Delta t)=u(t)+\Delta tf(u(t),t) $$
#
# This first guess is then used to solve for $u(t+\Delta t)$ using:
#
# $$ u(t+\Delta t)\approx u(t)+\frac{\Delta t}{2}\big(f(u(t),t)+f(\tilde{u}(t+\Delta t),t+\Delta t)\big)$$
#
# The generic term for schemes of this type is **predictor-corrector**. The initial calculation of $\tilde{u}(t+\Delta t)$ is used to predict the new value of $u$ and then this is used in a more accurate calculation to produce a more correct value.
#
# Note that Heun's method is $O(\Delta t^2)$, i.e. a second-order method.

# %% [markdown]
# ## <span style="color:blue">Exercise 2.6: Implementing Heun's method</span>
#
# Repeat the previous exercise for this method.
#
# For some ODEs you know the exact solution to compare the errors between Euler's and Heun's method, and how they vary with time step.

# %% [markdown]
# You should be able to get a plot that looks like this for the case $u'=u$.
#
# !["Comparison between the Euler and Heun method for the solution of a simple ODE."](images/euler_vs_heun.png)
